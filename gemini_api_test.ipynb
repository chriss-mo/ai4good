# %%
from nlp_utils import *
# Out:
# c:\Users\Chris Mo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# WARNING:tensorflow:From C:\Users\Chris Mo\AppData\Roaming\Python\Python311\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df_train = open_data('./data/liar-plus/train2.tsv')

# %%
df_train['statement'].iloc[0]
# Out:
# 'Says the Annies List political group supports third-trimester abortions on demand.'

# %%
import os
from google import genai

# Read the API key from the environment variable
api_key = os.environ.get("GEMINI_API_KEY")

if api_key:
    # Pass the key explicitly to the client
    client = genai.Client(api_key=api_key) 
    
    prompt = "Who won the last world series?"
    
    response = client.models.generate_content(
        model="gemini-2.5-pro", contents=prompt
    )
    
    print(response.text)
else:
    print("Error: GEMINI_API_KEY environment variable not found.")
# Out:
# Error: GEMINI_API_KEY environment variable not found.
